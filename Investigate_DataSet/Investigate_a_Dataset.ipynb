# %% [markdown]
# > **Tip**: Welcome to the Investigate a Dataset project! You will find tips in quoted sections like this to help organize your approach to your investigation. Before submitting your project, it will be a good idea to go back through your report and remove these sections to make the presentation of your work as tidy as possible. First things first, you might want to double-click this Markdown cell and change the title so that it reflects your dataset and investigation.
#
# # Project: Investigate TMDb Movie Data
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > I have select TMDb movie data set to explore. During the analysis, I will try to answer following questions.
# 1.Does runtime effect the budget? For instances, for longer movies, do we need more budget?
# 2.How budget,runtime and revenue is changing over time?
# 3.How popularity, vote and runtime is changing according to director?

# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.

# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html

import csv
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid", color_codes=True)
from numbers import Number
from scipy import stats
#allow plots and visualisations to be displayed in the report
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
# > **Tip**: In this section of the report, you will load in the data, check for cleanliness, and then trim and clean your dataset for analysis. Make sure that you document your steps carefully and justify your cleaning decisions.
#
# ### General Properties
# >I will load tmdb-movies dataset

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.
movie_df = pd.read_csv('tmdb-movies.csv')
movie_df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline      ...       \
# 0              The park is open.      ...
# 1             What a Lovely Day.      ...
# 2     One Choice Can Destroy You      ...
# 3  Every generation has a story.      ...
# 4            Vengeance Hits Home      ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning Part
# >In previous section, I have loaded the dataset and by displaying it, I have observed its properties.
# According to data analysis questions in the introduction part, I have decided to delete unuseful parts to make data more clear.
# And for the remaining parts, if NA content label occurs, I have also remove them. Because I have no chance to fulfill that parts by using mean and averages techniques.

# %%
#movie_df.info()
movie_df = pd.read_csv('tmdb-movies.csv')
del movie_df['id']
del movie_df['imdb_id']
del movie_df['homepage']
del movie_df['tagline']
del movie_df['overview']
del movie_df['release_date']
del movie_df['keywords']
del movie_df['production_companies']
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 13 columns):
# popularity        10866 non-null float64
# budget            10866 non-null int64
# revenue           10866 non-null int64
# original_title    10866 non-null object
# cast              10790 non-null object
# director          10822 non-null object
# runtime           10866 non-null int64
# genres            10843 non-null object
# vote_count        10866 non-null int64
# vote_average      10866 non-null float64
# release_year      10866 non-null int64
# budget_adj        10866 non-null float64
# revenue_adj       10866 non-null float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Observations:
# >After deleting unuseful parts, in dataset we have some inequalities for object value.
# Therefore we need to check null values.

# %%
#Display the total null values of all labels
movie_df.isnull().sum()
# Out:
# popularity         0
# budget             0
# revenue            0
# original_title     0
# cast              76
# director          44
# runtime            0
# genres            23
# vote_count         0
# vote_average       0
# release_year       0
# budget_adj         0
# revenue_adj        0
# dtype: int64

# %% [markdown]
# #### Observations:
# >It is seen that cast,director and genres labels have null values. From the dataset and label characteristics, it is not possible to fulfill these areas by looking their preceeding and proceeding values. So we need to clear that labels from dataset.

# %%
#cast,director,production_companies tabs have missing parts. So we need to fix them.
clean_data = movie_df.dropna()
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10732 entries, 0 to 10865
# Data columns (total 13 columns):
# popularity        10732 non-null float64
# budget            10732 non-null int64
# revenue           10732 non-null int64
# original_title    10732 non-null object
# cast              10732 non-null object
# director          10732 non-null object
# runtime           10732 non-null int64
# genres            10732 non-null object
# vote_count        10732 non-null int64
# vote_average      10732 non-null float64
# release_year      10732 non-null int64
# budget_adj        10732 non-null float64
# revenue_adj       10732 non-null float64
# dtypes: float64(4), int64(5), object(4)
# memory usage: 1.1+ MB

# %%
#Check clean data has a null value or not to be sure
clean_data.isnull().sum()
# Out:
# popularity        0
# budget            0
# revenue           0
# original_title    0
# cast              0
# director          0
# runtime           0
# genres            0
# vote_count        0
# vote_average      0
# release_year      0
# budget_adj        0
# revenue_adj       0
# dtype: int64

# %% [markdown]
# #### Observations:
# >After cleaning the null parts, all labels of dataset have the same value count. And with null.sum, it is double-checked.

# %%
#After cleaning na parts from data, we can look correlations between dataset variables.
clean_data.corr()
# Out:
#               popularity    budget   revenue   runtime  vote_count  \
# popularity      1.000000  0.544231  0.662841  0.138279    0.800618
# budget          0.544231  1.000000  0.734460  0.192149    0.632057
# revenue         0.662841  0.734460  1.000000  0.164285    0.790889
# runtime         0.138279  0.192149  0.164285  1.000000    0.164971
# vote_count      0.800618  0.632057  0.790889  0.164971    1.000000
# vote_average    0.217901  0.087265  0.178499  0.177299    0.260559
# release_year    0.093038  0.119031  0.059049 -0.119304    0.110303
# budget_adj      0.512094  0.968881  0.705931  0.222631    0.586287
# revenue_adj     0.608382  0.621782  0.918990  0.177407    0.707518
#
#               vote_average  release_year  budget_adj  revenue_adj
# popularity        0.217901      0.093038    0.512094     0.608382
# budget            0.087265      0.119031    0.968881     0.621782
# revenue           0.178499      0.059049    0.705931     0.918990
# runtime           0.177299     -0.119304    0.222631     0.177407
# vote_count        0.260559      0.110303    0.586287     0.707518
# vote_average      1.000000     -0.127803    0.099885     0.199440
# release_year     -0.127803      1.000000    0.019401    -0.064970
# budget_adj        0.099885      0.019401    1.000000     0.645918
# revenue_adj       0.199440     -0.064970    0.645918     1.000000

# %% [markdown]
# #### Observations:
# >In above correlation table, we can see that correlation between each label, which are integer properties.
# By looking correlation factor at first glance, most correlated data labels and less correlateds can be seen.
# There are some negative correlation factors, for example runtime and release year, negativeness implies that there is a cross relation between these labels. In other words, when one of the label is increasing, other one is decreasing.
# In following part, histogram of each data label will be shown.

# %%
#In order to see data distribution of labels histograms are shown below.
clean_data.hist();

# %% [markdown]
# #### Observations:
# > Histogram of the labels show similar inditications like correlation table. It is clearly seen that release year and runtime have opposite characteristic.

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
# ### Research Question 1
#
# ### Runtime and Budget Relationship
#
# > First I want to explore the relation between runtime and budget.Because in correlation diagram, it is seen that runtime and budget has correlation around 0.2. Which indicates that when we plot the relation, result should be scattered.

# %%
sns.factorplot(data=clean_data, x='runtime', y='budget',size=5, aspect=.8)
plt.title('Runtime vs Budget');
plt.show()

# %%
plt.scatter(x=clean_data['runtime'], y=clean_data['budget']);
plt.xlabel('Runtime')
plt.ylabel('Budget')
plt.title('Runtime vs Budget');

# %% [markdown]
# #### Observations:
# >For observing relationship between runtime and budget, I have used two different plot option factorplot and scatter. For me, observing with scatter is easier.By looking at graph we can say that, until some point like 170, there is a strong relationship between runtime and budget. Both increases. However after that point, when runtime increases, budget does not increase, it has decreasing property but at some points, budget has outliers.
# And movie which has the most budget is not the longest one.
# Interesting part is there are some movies which they do not need any budget.

# %% [markdown]
# ### Research Question 2
#
# ### How budget, runtime and popularity is changing over average vote?
#
# >In order to investigate, this problem first dataset should be modified according to average_vote.
# Because our main three questionere label will be changed to average vote value.

# %%
voting_data = clean_data.groupby('vote_average')
voting_data.head()
# Out:
#        popularity     budget     revenue  \
# 0       32.985763  150000000  1513528810
# 1       28.419936  150000000   378436354
# 2       13.112507  110000000   295238201
# 3       11.173104  200000000  2068178225
# 4        9.335014  190000000  1506249360
# 5        9.110700  135000000   532950503
# 6        8.654359  155000000   440603537
# 7        7.667400  108000000   595380321
# 8        7.404165   74000000  1156730962
# 9        6.326804  175000000   853708609
# 7235   Casper Van Dien|Erika Eleniak|Coolio|Grant Swa...
# 7772   Matthew Wolf|Amy Weber|Shaley Scott|Eliza Swen...
# 8062   Jeffrey Byron|Michael Preston|Tim Thomerson|Ke...
# 8221   Martin Scorsese|Brian De Palma|Gregory Peck|Fr...
# 8411   Freddie Mercury|Roger Taylor|John Deacon|Brian...
# 8839                                      Dave Chappelle
# 9291   Adam Sandler|Scott LaRose|Tom Hodges|Lisa Coll...
# 9315   Jim Lovell|Russell Schweickart|Eugene Cernan|M...
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...
#
#                                    director  runtime  \
# 0                           Colin Trevorrow      124
# 1                             George Miller      120
# 2                          Robert Schwentke      119
# 3                               J.J. Abrams      136
# 4                                 James Wan      137
# 5            Alejandro GonzÃ¡lez IÃ±Ã¡rritu      156
# 6                               Alan Taylor      125
# 7                              Ridley Scott      141
# 8                  Kyle Balda|Pierre Coffin       91
# 9                               Pete Docter       94
# 10                               Sam Mendes      148
# 11           Lana Wachowski|Lilly Wachowski      124
# 12                             Alex Garland      108
# 13                           Chris Columbus      105
# 14                              Joss Whedon      141
# 15                        Quentin Tarantino      167
# 16                          Olivier Megaton      109
# 17                              Peyton Reed      115
# 18                          Kenneth Branagh      112
# 19                         Francis Lawrence      136
# 20                                Brad Bird      130
# 21                            Antoine Fuqua      123
# 22                              Brad Peyton      114
# 23                       Sam Taylor-Johnson      125
# 24                               Adam McKay      130
# 25                    Christopher McQuarrie      131
# 26                          Seth MacFarlane      115
# 27                           Matthew Vaughn      130
# 28                             Tom McCarthy      128
# 29                                 Wes Ball      132
# ...                                     ...      ...
# 4164                            Adam Curtis      235
# 4178                         Frank Darabont      142
# 4642                           Brandon Nutt       90
# 4717          Dale Fabrigar|Everette Wallin       90
# 4773                          Dominic Burns      101
# 4859                      Lawrence Kasanoff       87
# 4882                            Brett Kelly       75
# 4910                         Justin Russell       90
# 5663                             Craig Moss       80
# 5682                               Uwe Boll       85
# 5844                           John Gulager       88
# 5923                        Anthony Mandler       27
# 5933                         David DeCoteau       83
# 5940                          Marco Ristori       90
# 5986                 Jorge RamÃ­rez SuÃ¡rez      119
# 6077                             Jared Cohn       85
# 6404                        Jessica Nilsson       91
# 6441                          Ã‡aÄŸan Irmak      108
# 6900                          Tibor TakÃ¡cs       90
# 6911                           David Mallet      145
# 7220                              Bob Clark       88
# 7235                    Darrell James Roodt       86
# 7772                            Leigh Scott       86
# 8062                           Charles Band       84
# 8221   Martin Scorsese|Michael Henry Wilson      225
# 8411                           Saul Swimmer      138
# 8839                            Stan Lathan       57
# 9291                        Valerie Breiman       99
# 9315                             Al Reinert       80
# 10865                      Harold P. Warren       74
#
#                                                 genres  vote_count  \
# 0            Action|Adventure|Science Fiction|Thriller        5562
# 1            Action|Adventure|Science Fiction|Thriller        6185
# 2                   Adventure|Science Fiction|Thriller        2480
# 3             Action|Adventure|Science Fiction|Fantasy        5292
# 4                                Action|Crime|Thriller        2947
# 5                     Western|Drama|Adventure|Thriller        3929
# 6            Science Fiction|Action|Thriller|Adventure        2598
# 7                      Drama|Adventure|Science Fiction        4572
# 2.1            2008.333333  0.000000e+00  3.505405e+06
# 2.2            2012.333333  2.057779e+07  2.333395e+04
# 2.3            1996.500000  0.000000e+00  0.000000e+00

# %%
vote_mean['popularity'].hist(bins=10);
plt.xlabel('Popularity')
plt.ylabel('Counts')
plt.title('Popularity Over Votes');

# %% [markdown]
# #### Observations:
# > Popularity among vote_average has higher around 0.5

# %%
vote_mean['budget'].hist(bins=50);
plt.xlabel('Budget')
plt.ylabel('Counts')
plt.title('Budget Over Votes');

# %% [markdown]
# #### Observations:
# > Here I have changed bins of histogram to see data more clearly.
# > Budget among votes has higher distribution around 0.02e7. After that we can say that, budget count does not oscillate too much.

# %%
vote_mean['runtime'].hist(bins=50);
plt.xlabel('Runtime')
plt.ylabel('Counts')
plt.title('Runtime Over Votes');

# %% [markdown]
# #### Observations:
# > Among the votes, shorter movies has higher ratings.

# %% [markdown]
# ### Research Question 3
#
# ### How popularity, vote and runtime is changing according to director?
#
# > Like previous step, I will make necessary modifications in dataset according to director name.
# First, I will group data by director name and define this in a new dataframe.

# %%
director_data=clean_data.groupby('director')
director_data.head()
# Out:
#        popularity     budget     revenue  \
# 0       32.985763  150000000  1513528810
# 1       28.419936  150000000   378436354
# 2       13.112507  110000000   295238201
# 3       11.173104  200000000  2068178225
# 4        9.335014  190000000  1506249360
# 5        9.110700  135000000   532950503
# 6        8.654359  155000000   440603537
# 7        7.667400  108000000   595380321
# 8        7.404165   74000000  1156730962
# 9        6.326804  175000000   853708609
# 10       6.200282  245000000   880674609
# 11       6.189369  176000003   183987723
# 12       6.118847   15000000    36869414
# 13       5.984995   88000000   243637091
# 14       5.944927  280000000  1405035767
# 15       5.898400   44000000   155760117
# 16       5.749758   48000000   325771424
# 17       5.573184  130000000   518602163
# 18       5.556818   95000000   542351353
# 19       5.476958  160000000   650523427
# 20       5.462138  190000000   209035668
# 21       5.337064   30000000    91709827
# 22       4.907832  110000000   470490832
# 23       4.710402   40000000   569651467
# 24       4.648046   28000000   133346506
# 25       4.566713  150000000   682330139
# 26       4.564549   68000000   215863606
# 27       4.503789   81000000   403802136
# 28       4.062293   20000000    88346473
# 29       3.968891   61000000   311256926
# ...           ...        ...         ...
# 10812    0.318883          0     5438927
# 10813    0.073425          0           0
# 10814    0.072267          0           0
# 10815    0.065504    3000000           0
# 10816    0.064602          0           0
# 10818    0.047645          0           0
# 10820    1.227582     315000           0
# 10821    0.929393          0           0
# 10823    0.613444          0           0
# 10825    0.509263          0           0
# 10826    0.418900          0           0
# 10827    0.410366    1377800           0
# 10829    0.395668    4653000     6000000
# 10833    0.737730          0           0
# 10836    0.239435          0           0
# 10838    0.151845          0           0
# 10839    0.276133          0           0
# 10841    0.264925      75000           0
# 10842    0.253437          0           0
# 10843    0.252399          0           0
# 10844    0.236098          0           0
# 10850    0.202473          0           0
# 10851    0.342791          0           0
# 10852    0.227220          0           0
# 10855    0.141026     700000           0
# 10856    0.140934          0           0
# 10857    0.131378          0           0
# 10861    0.080598          0           0
# 10863    0.065141          0           0
# 10865    0.035919      19000           0
# 10826                  Fred Zinnemann      120
# 10827             Leslie H. Martinson      105
# 10829                    Howard Hawks      120
# 10833                   William Wyler      123
# 10836                 Charles Walters      114
# 10838                  Richard Brooks      117
# 10839                   Bill Melendez       25
# 10841                   Monte Hellman       82
# 10842             Wolfgang Reitherman       25
# 10843    Basil Dearden|Eliot Elisofon      134
# 10844                     Daniel Mann      108
# 10850                     Jack Smight      121
# 10851                      James Hill       95
# 10852                    Fielder Cook       95
# 10855                     Alan Rafkin       90
# 10856                    Norman Tokar       93
# 10857                  Henry Hathaway      128
# 10861                     Bruce Brown       95
# 10863                  Eldar Ryazanov       94
# 10865                Harold P. Warren       74
#
#                                                 genres  vote_count  \
# 0            Action|Adventure|Science Fiction|Thriller        5562
# 1            Action|Adventure|Science Fiction|Thriller        6185
# 2                   Adventure|Science Fiction|Thriller        2480
# 3             Action|Adventure|Science Fiction|Fantasy        5292
# 4                                Action|Crime|Thriller        2947
# 5                     Western|Drama|Adventure|Thriller        3929
# 6            Science Fiction|Action|Thriller|Adventure        2598
# 7                      Drama|Adventure|Science Fiction        4572
# 8                    Family|Animation|Adventure|Comedy        2893
# 9                              Comedy|Animation|Family        3935
# 10                              Action|Adventure|Crime        3254
# 11            Science Fiction|Fantasy|Action|Adventure        1937
# 12                               Drama|Science Fiction        2854
# 13                       Action|Comedy|Science Fiction        1575
# 14                    Action|Adventure|Science Fiction        4304
# 15                         Crime|Drama|Mystery|Western        2389
# 16                               Crime|Action|Thriller        1578
# 17                    Science Fiction|Action|Adventure        3779
# 18                        Romance|Fantasy|Family|Drama        1495
# 19                       War|Adventure|Science Fiction        2380
# 20     Action|Family|Science Fiction|Adventure|Mystery        1899
# 21                                        Action|Drama        1386
# 22                               Action|Drama|Thriller        2060
# 23                                       Drama|Romance        1865
# 24                                        Comedy|Drama        1545
# 25                                              Action        2349
# 26                                              Comedy        1666
# 27                       Crime|Comedy|Action|Adventure        3833
# 28                              Drama|Thriller|History        1559
# 29                     Action|Science Fiction|Thriller        1849
# ...                                                ...         ...
# 10812                 Thriller|Adventure|History|Drama          10
# 10813                         Science Fiction|TV Movie          12
# 10814                    Comedy|Family|Science Fiction          14
# 10815                                Drama|Romance|War          16
# 10816                                           Comedy          14
# 10818                          Horror|Thriller|Mystery          17
# 10820                          Animation|Family|Comedy         286
# 10821                            Drama|Science Fiction          93
# 10823                         Action|Adventure|Fantasy          17
# 10825                           Drama|Mystery|Thriller         103
# 10826                                    Drama|History          29
# 10827    Family|Adventure|Comedy|Science Fiction|Crime          99
# 10829                                   Action|Western          36
# 10833                             Comedy|Crime|Romance          67
# 10836                                   Comedy|Romance          11
# 10838                         Action|Adventure|Western          21
# 10839                                 Family|Animation          49
# 10841                                          Western          12
# 10842                                 Animation|Family          12
# 10843               Adventure|Drama|War|History|Action          12
# 10844         Adventure|Comedy|Fantasy|Science Fiction          13
# 10850              Action|Drama|Thriller|Crime|Mystery          14
# 10851            Adventure|Drama|Action|Family|Foreign          15
# 10852                                          Western          11
# 10855                    Comedy|Family|Mystery|Romance          14
# 10850           6.0          1966  0.000000e+00  0.000000e+00
# 10851           6.6          1966  0.000000e+00  0.000000e+00
# 10852           6.0          1966  0.000000e+00  0.000000e+00
# 10855           6.1          1966  4.702610e+06  0.000000e+00
# 10856           5.7          1966  0.000000e+00  0.000000e+00
# 10857           5.9          1966  0.000000e+00  0.000000e+00
# 10861           7.4          1966  0.000000e+00  0.000000e+00
# 10863           6.5          1966  0.000000e+00  0.000000e+00
# 10865           1.5          1966  1.276423e+05  0.000000e+00
#
# [9148 rows x 13 columns]

# %%
clean_data['director'].value_counts()
# Out:
# Woody Allen                                                                                         45
# Clint Eastwood                                                                                      34
# Steven Spielberg                                                                                    29
# Martin Scorsese                                                                                     28
# Ridley Scott                                                                                        23
# Steven Soderbergh                                                                                   22
# Ron Howard                                                                                          22
# Joel Schumacher                                                                                     21
# Brian De Palma                                                                                      20
# Barry Levinson                                                                                      19
# Wes Craven                                                                                          19
# Tim Burton                                                                                          18
# John Carpenter                                                                                      18
# Rob Reiner                                                                                          18
# David Cronenberg                                                                                    18
# Mike Nichols                                                                                        18
# Stephen Frears                                                                                      17
# Francis Ford Coppola                                                                                17
# Oliver Stone                                                                                        17
# Walter Hill                                                                                         17
# Norman Jewison                                                                                      17
# Sidney Lumet                                                                                        17
# Spike Lee                                                                                           17
# Peter Hyams                                                                                         17
# Renny Harlin                                                                                        17
# Tyler Perry                                                                                         17
# Robert Zemeckis                                                                                     17
# Richard Linklater                                                                                   16
# Uwe Boll                                                                                            16
# Roman Polanski                                                                                      16
#                                                                                                     ..
# Scott Sanders                                                                                        1
# Matthew O'Callaghan                                                                                  1
# Jody Lee Lipes                                                                                       1
# Robert J. Rosenthal                                                                                  1
# Chris Malloy                                                                                         1
# Michael Goldenberg                                                                                   1
# Brian Clemens                                                                                        1
# Boudewijn Koole                                                                                      1
# Donald G. Jackson|R.J. Kizer                                                                         1
# Michael Taverna                                                                                      1
# Isaac Feder                                                                                          1
# Todd Berger                                                                                          1
# Nicholas Jasenovec                                                                                   1
# John Paragon                                                                                         1
# Pamela Romanowsky                                                                                    1
# Jon Burton                                                                                           1
# Yasuhiro Aoki|Futoshi Higashide|Toshiyuki Kubooka|Hiroshi Morioka|Jong-Sik Nam|Shoujirou Nishimi     1
# Manny Rodriguez|Jay Lavender                                                                         1
# Ryan Fleck                                                                                           1
# Doug Pray                                                                                            1
# Richard A. Colla|Alan J. Levi                                                                        1
# Michael Rowe                                                                                         1
# Vlad Yudin                                                                                           1
# Ariel Zeitoun|Julien Seri                                                                            1
# Garrett Brawith                                                                                      1
# Oxide Pang Chun|Danny Pang                                                                           1
# Alberto RodrÃ­guez                                                                                   1
# Sarah Burns|Ken Burns                                                                                1
# Sam Garbarski                                                                                        1
# Stanley Tong                                                                                         1
# Name: director, Length: 5018, dtype: int64

# %% [markdown]
# #### Observations:
# >Here we can see that all director and director combinations and its movie counts. As it can be seen, I didnt seperate the movies which has more than one director and I did not include them into single director name.

# %%
#In order to see most popular 5 director,list them like
popular_director = clean_data['director'].value_counts()
popular_director[:5]
# Out:
# Woody Allen         45
# Clint Eastwood      34
# Steven Spielberg    29
# Martin Scorsese     28
# Ridley Scott        23
# Name: director, dtype: int64

# %% [markdown]
# #### Observations:
# > Most popular director is Woody Allen in the dataset and Clint Eastwood follows him.

# %%
director_mean = director_data.mean()
director_mean.head()
# Out:
#                             popularity       budget     revenue  runtime  \
# director
#  FrÃ©dÃ©ric Jardin            0.434506    2500000.0      3358.0     98.0
# A. Todd Smith                 1.876037          0.0         0.0      0.0
# A.R. Murugadoss               0.215030    9100000.0  76000000.0    183.0
# Aaron Aites                   0.108700          0.0         0.0     93.0
# Aaron Blaise|Robert Walker    1.653031  100000000.0       250.0     85.0
#
#                             vote_count  vote_average  release_year  \
# director
#  FrÃ©dÃ©ric Jardin                28.0           5.9        2011.0
# A. Todd Smith                     11.0           5.4        2015.0
# A.R. Murugadoss                   53.0           6.9        2008.0
# Aaron Aites                       13.0           6.5        2008.0
# Aaron Blaise|Robert Walker       753.0           6.8        2003.0
#
#                               budget_adj   revenue_adj
# director
#  FrÃ©dÃ©ric Jardin          2.423495e+06  3.255239e+03
# A. Todd Smith               0.000000e+00  0.000000e+00
# A.R. Murugadoss             9.216358e+06  7.697178e+07
# Aaron Aites                 0.000000e+00  0.000000e+00
# Aaron Blaise|Robert Walker  1.185353e+08  2.963382e+02

# %% [markdown]
# #### Observations:
# >In order to see director's individual data, average values of labels and their distribution should be calculated which is general average and deviation. For this I have used grouped dataframe and take average of every data point corresponding to that group. By this way, I can get director based data within whole dataset in average form.
# For example, by looking above dataframe part, it can be said that A.Todd Smith's popularity is 1.87 and its average budget for making a movie is 25000000 etc.

# %%
director_mean['popularity'].nlargest()
# Out:
# director
# Colin Trevorrow                16.696886
# Joe Russo|Anthony Russo        12.971027
# Chad Stahelski|David Leitch    11.422751
# Don Hall|Chris Williams         8.691294
# Juno John Lee                   8.411577
# Name: popularity, dtype: float64

# %% [markdown]
# #### Observations:
# > By using nlargest function, we can see the director which has largest popularity.
# > In previous section, we see that Woody Allen has the highest movie count in dataset, however most popular director is Colin Trevorrow.

# %%
director_mean['popularity'].hist();
plt.xlabel('Popularity')
plt.ylabel('Counts')
plt.title('Popularity Among Directors');

# %%
director_mean['runtime'].hist(bins=10);
plt.xlabel('Runtime')
plt.ylabel('Counts')
plt.title('Runtime Among Directors');

# %% [markdown]
# #### Observations:
# > Most popular runtime among the directors between 100 and 180

# %%
director_mean['revenue'].hist();
plt.xlabel('Revenue')
plt.ylabel('Counts')
plt.title('Revenue Among Directors');

# %% [markdown]
# #### Observations:
# > Most popular revenue range for director is 0 to 0.1e9. Revenue is going up to 0.8e9 but that kind of values are not common.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
# > I have listed my observations after nearly every step. However in general I have tried to observe;
# 1. Relationship between in all data by looking correlation diagram/table
# 2. Runtime and Budget relationship without making any specifications
# 3. Relationships filtered by average vote and director
# 4. Most common director and most popular director and directors runtime and budget choice
#
# >There are some missing parts in the dataset and fulfilling them is not possible. Therefore, data lost is occurs.
# >In order to make statistical observations, I have used stackoverflow post to find out best way.

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 0
